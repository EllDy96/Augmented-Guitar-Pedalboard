# %% [markdown]
# <a href="https://colab.research.google.com/github/EllDy96/MAE_Thesis/blob/main/sEMG_binary_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the libraries and creating a connection wiht my google drive to import the Datasets.

# %%
#!pip install tensorflow==2.12.0
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('GPU device not found')
  #raise SystemError('GPU device not found')    
else:
  print('I Found a GPU! at: {}'.format(device_name))
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sklearn
import pandas as pd
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import LSTM, Dense, Input, Reshape , Dropout
from sklearn import preprocessing
from keras.regularizers import l1
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
plt.style.use('seaborn')

from google.colab import drive
drive.mount('/content/drive') # now I can import files from my Drive
# Out:
# GPU device not found
# <ipython-input-1-3ca56d057524>:26: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# Mounted at /content/drive

# %%
#!nvidia-smi # it list the availabe GPUs

# %% [markdown]
# # Better to use a LSTM
# We want to track a time series input data, better handle by LSTM Recurrent NN. Now let's try to implment it
# First, I need to define your LSTM model architecture using Keras. The architecture can be defined using the Sequential API in Keras.
#
# In my case I have an 8  input channel, each linked to a specific sEMG stream coming from a specific muscle.In DL the column of the training set are called features, hence I have 8 feautures.
# To enable the LSTM network to keep track of the different activation amounts between the eight channels we need to define a input Dense layer whit shape (num_smaple, 8). We feed each of the 8 neurons whit a specific channel. Then we add a LSTM with 64 neurons and a final Dense layer with 5 neurons and a sigmoid activation function to span the result from 0 to one. the sigmoid function maps any real-valued number to a value between 0 and 1, it is a commonly used nonlinear activation function in neural networks. It is defined as:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Importing the sEMG pandas datasets

# %% [markdown]
#
# To define the target set, it is necessary to ensure that its first dimension matches that of the training set (the number of rows). We have a training set of shape(num_samples,1, 8), it means with 8 features each wiht dimension 1. We want to have a 5 floats outputs so we need to define a target set of num_sample rows and 5 targets (5 output features).

# %% [markdown]
# The training set and the target set has to have the same number of rows, in this case we select 30000 rows that rappresents 30000 time steps of 8 sample each.

# %% [markdown]
# ## Target dataset

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Training dataset packing
#
#
# Here I pack my input data to feed them to the Model during the training process. Furthemore we split the Training dataset in two part, one for the training process and one for the evalution, called Test set.

# %%
scaler = MinMaxScaler()
pd_dataframe= {
    'arpeggio': pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_arpeggio_rms'),
    'strumming': pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_strumming_rms'),
    'bending': pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_bending_rms'),
    'doublePick':pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_doublePick_rms'),
    'strongPick':pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_strongPick_rms'),
    'tapping':pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_tapping_rms'),
    'pullOffHammerOn': pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sEMG_pandas_dataset/csv_pd_dataframe/df_pullOffHammerOn_rms')
}


#be sure that all the column has the same name otherwise pd.concat will create another column 
new_columns_name = ['RMS_ Brachioradialis  Sx ', 'RMS_ Brachioradialis  Dx ',
       'RMS_ Extensor Carpi Radialis Sx ', 'RMS_ Extensor Carpi Radialis  Dx ',
       'RMS_ Triceps brachii Long Head Dx ', 'RMS_ Deltoid  Lateral  Dx ',
       'RMS_ Abductor digiti minimi (hand) Sx ',
       'RMS_ Abductor digiti minimi (hand) Dx']


#I need to implement a binary classifier
#using the function pd.concat i can concatenate multiple pd dataframe 

dataframes_class_0 = ['arpeggio', 'bending', 'strongPick']
concatenated_df_class0 = pd.concat([pd_dataframe[df] for df in dataframes_class_0], axis=0)

dataframes_class_1 = ['strumming', 'doublePick', 'tapping','pullOffHammerOn']
for i in dataframes_class_1:
  pd_dataframe[i].columns = new_columns_name
#print([pd_dataframe[df].columns for df in dataframes_class_1])
concatenated_df_class1 = pd.concat([pd_dataframe[df] for df in dataframes_class_1], axis=0)

print(concatenated_df_class1.shape)

pd_binary_df ={
    'calm': concatenated_df_class0,
    'frenetic': concatenated_df_class1
}

for i in pd_binary_df:
  #remamber: the training set has to look like (samples, time_steps, features)
  #now we have to group the input data to create a 2D matrix of shape (time_steps, features) 
  #pd_dataframe[i]= pd_dataframe[i].iloc[5000:35031].values # excluding the first and the last 5 second of samples
  pd_binary_df[i] = scaler.fit_transform(pd_binary_df[i])
  # Define the sequence length
  # Define the sequence length
  sequence_length = 32

  # Calculate the number of groups
  num_groups = pd_binary_df[i].shape[0] // sequence_length

  # Calculate the number of remaining elements
  num_remaining = pd_binary_df[i].shape[0] % sequence_length

  # Reshape the input data into a 3D matrix
  input_sequences = np.reshape(pd_binary_df[i][:num_groups * sequence_length], (num_groups, sequence_length, pd_binary_df[i].shape[1]))
  pd_binary_df[i] = input_sequences     


  # The shape of 'input_sequences' will be (num_groups + 1, sequence_length, num_features)
  print(input_sequences.shape)

  #pd_dataframe[i]= np.reshape(pd_dataframe[i],(pd_dataframe[i].shape[0], 1, pd_dataframe[i].shape[1]))


#Printing some statistics 
for i in pd_binary_df.keys():
  print('mean and variance and shape of', i ,' = {:.3f}, {:.3f}, {}'.format(np.mean(pd_binary_df[i]), np.var(pd_binary_df[i]), pd_binary_df[i].shape ))
# Out:
# (170461, 8)
# (3909, 32, 8)
# (5326, 32, 8)
# mean and variance and shape of calm  = 0.102, 0.024, (3909, 32, 8)
# mean and variance and shape of frenetic  = 0.093, 0.020, (5326, 32, 8)

# %%
target_dict = {
  'calm': 0,
  'frenetic': 1
}
shape1= pd_binary_df['calm'].shape[0]
#populate the dictionaty with the right shapes before using them as target set
#i have to create a target set with 938 rows and 7 columns 
for i in target_dict:  
  target_dict[i]= np.tile(target_dict[i], (pd_binary_df[i].shape[0],1))

print([i.shape for i in  target_dict.values()])
# Out:
# [(3909, 1), (5326, 1)]

# %%
concatenated_training_datasets= np.concatenate(([pd_binary_df[key] for key in pd_binary_df.keys()]),axis=0)
#print(x_train.shape)
concatenated_target_datasets= np.concatenate(([target_dict[key] for key in target_dict.keys()]), axis= 0)
#print(y_train.shape)
#splitting the dataset into a training and testing dataset

X_train, X_test, Y_train, Y_test = train_test_split(concatenated_training_datasets, concatenated_target_datasets, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (7388, 32, 8) (1847, 32, 8) (7388, 1) (1847, 1)

# %% [markdown]
# It does not have any senso to put as a imput layer a dense layer. it distracts the LSTM from the time-series analysis, the input layer before the lstm is usualy used when you have a higher values of input features, and you want to do some inference before classify the time series data. The input dense of CNN layer is used to reduce the number of features (parameters) before feed the LSTM. In this case we do not need to use a input dense layer because the number of features is low. We can use it after the LSTM if it encrease the performance.

# %%
time_steps =32 #we feed the model with 32 consecuitive samples to  discover the pattern 
n_features =8 # we have 8 sEMG sample for each  new input sample it means 8 features  for each sample 

input_shape= (time_steps, n_features)# each sample of new data is rappresented by 8 time steps in our dataset and each time step has feauture shape of 1
#n_features is the number of features or variables at each time step.

model = Sequential()
#By setting the input shape to (8, 1), you are specifying that each sample consists of 8 time steps, each time step consisting of a single feature
# Add an input dense layer with 8 neurons, one for each column in the input dataset


# Add an LSTM layer with 64 units
model.add(LSTM(64, input_shape= input_shape ,return_sequences=True, kernel_regularizer=l1(0.1))) # when you want to stack multiple LSTM 
#you have to set the return_sequences=True to not have shape problems. 

model.add(Dropout(0.3))  # add a dropout layer with dropout rate of 0.2
model.add(LSTM(32, return_sequences=False))
# Add a dense output layer with 5 units and linear activation
model.add(Dense(1, activation='sigmoid')) #return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence. Default: False. IT should be set true only in the output layer 

print('The output shape: ',model.output_shape)
model.summary()
# Out:
# The output shape:  (None, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32, 64)            18688
#
#  dropout (Dropout)           (None, 32, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 31,137
# Trainable params: 31,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the Model
# To compile the network (before training it) we have to choose the Optimizer and the loss function:
#
# The optimizer is the algorithm used to update the weights of the model during training, and 'adam' is a popular optimizer that adapts the learning rate of each weight based on the first and second moments of the gradients.
#
# The loss function is used to measure how well the model is performing on the training data and guides the optimization process. 'mse' stands for mean squared error, which is a common loss function used for regression problems where the goal is to minimize the difference between the predicted and actual values.
#
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#
# Learning rate: The learning rate determines how much the model weights are updated during training. A larger learning rate can lead to faster convergence, but can also cause the model to overshoot the minimum.

# %% [markdown]
# Showing the availables parameters of the network

# %%
# Compile the model

#model.compile(optimizer='adam', loss='mse', metrics=['mse'])

#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
"""
# Load data from pandas dataframe dictionary
X_1 = pd_dataframe['arpeggio'] # Return a Numpy representation of the DataFrame. Only the values in the DataFrame will be returned, the axes labels will be removed.
#print(type(X_1))
X_1= tf.stack(X_1)
y_1 = target_dict['arpeggio']

X_2 = pd_dataframe['strumming'] # Return a Numpy representation of the DataFrame. Only the values in the DataFrame will be returned, the axes labels will be removed.
print(type(X_2))
X_2= tf.stack(X_2)
y_2 = target_dict['strumming']
print('output shape ', y_1.shape, ' input shape  ', X_1.shape )
"""
#print( [pd_dataframe[key] for key in pd_dataframe.keys()])

# Fit the model with different datates each associated to a specific output target
#create a list of datasets tuple to train the model 
history = model.fit(X_train,Y_train, validation_split=0.25, epochs=500)
# Out:
# Epoch 1/500
# 174/174 [==============================] - 12s 42ms/step - loss: 5.3186 - accuracy: 0.7371 - val_loss: 0.6874 - val_accuracy: 0.7477
# Epoch 2/500
# 174/174 [==============================] - 8s 43ms/step - loss: 0.6057 - accuracy: 0.7724 - val_loss: 0.5124 - val_accuracy: 0.8138
# Epoch 3/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.5313 - accuracy: 0.7993 - val_loss: 0.5127 - val_accuracy: 0.8197
# Epoch 4/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.4971 - accuracy: 0.8249 - val_loss: 0.4626 - val_accuracy: 0.8387
# Epoch 5/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.4803 - accuracy: 0.8325 - val_loss: 0.4304 - val_accuracy: 0.8522
# Epoch 6/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.4512 - accuracy: 0.8415 - val_loss: 0.4180 - val_accuracy: 0.8690
# Epoch 7/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.4337 - accuracy: 0.8580 - val_loss: 0.4067 - val_accuracy: 0.8744
# Epoch 8/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.4330 - accuracy: 0.8574 - val_loss: 0.4195 - val_accuracy: 0.8500
# Epoch 9/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.4312 - accuracy: 0.8562 - val_loss: 0.4718 - val_accuracy: 0.8240
# Epoch 10/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.4238 - accuracy: 0.8630 - val_loss: 0.3956 - val_accuracy: 0.8744
# Epoch 11/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.4138 - accuracy: 0.8668 - val_loss: 0.3955 - val_accuracy: 0.8814
# Epoch 12/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.4014 - accuracy: 0.8766 - val_loss: 0.3929 - val_accuracy: 0.8863
# Epoch 13/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.4115 - accuracy: 0.8704 - val_loss: 0.4019 - val_accuracy: 0.8766
# Epoch 14/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.4025 - accuracy: 0.8753 - val_loss: 0.4651 - val_accuracy: 0.8414
# Epoch 15/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.4015 - accuracy: 0.8766 - val_loss: 0.4014 - val_accuracy: 0.8711
# Epoch 16/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3964 - accuracy: 0.8753 - val_loss: 0.4290 - val_accuracy: 0.8630
# Epoch 17/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3955 - accuracy: 0.8807 - val_loss: 0.3845 - val_accuracy: 0.8803
# Epoch 18/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3924 - accuracy: 0.8775 - val_loss: 0.3939 - val_accuracy: 0.8863
# Epoch 19/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3836 - accuracy: 0.8832 - val_loss: 0.3906 - val_accuracy: 0.8793
# Epoch 20/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3831 - accuracy: 0.8867 - val_loss: 0.3714 - val_accuracy: 0.8993
# Epoch 21/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3922 - accuracy: 0.8773 - val_loss: 0.3785 - val_accuracy: 0.8776
# Epoch 22/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3903 - accuracy: 0.8737 - val_loss: 0.4519 - val_accuracy: 0.8305
# Epoch 23/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3814 - accuracy: 0.8868 - val_loss: 0.4108 - val_accuracy: 0.8755
# Epoch 24/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3828 - accuracy: 0.8834 - val_loss: 0.4194 - val_accuracy: 0.8646
# Epoch 25/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3974 - accuracy: 0.8773 - val_loss: 0.3915 - val_accuracy: 0.8733
# Epoch 26/500
# 174/174 [==============================] - 7s 37ms/step - loss: 0.3819 - accuracy: 0.8876 - val_loss: 0.3721 - val_accuracy: 0.8836
# Epoch 27/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3796 - accuracy: 0.8883 - val_loss: 0.4348 - val_accuracy: 0.8587
# Epoch 28/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3801 - accuracy: 0.8872 - val_loss: 0.3804 - val_accuracy: 0.8858
# Epoch 29/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3743 - accuracy: 0.8894 - val_loss: 0.4397 - val_accuracy: 0.8646
# Epoch 30/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.4004 - accuracy: 0.8785 - val_loss: 0.3957 - val_accuracy: 0.8749
# Epoch 31/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3895 - accuracy: 0.8785 - val_loss: 0.4183 - val_accuracy: 0.8609
# Epoch 32/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3850 - accuracy: 0.8874 - val_loss: 0.3890 - val_accuracy: 0.8814
# Epoch 33/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3670 - accuracy: 0.8910 - val_loss: 0.3567 - val_accuracy: 0.9009
# Epoch 34/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3682 - accuracy: 0.8910 - val_loss: 0.4429 - val_accuracy: 0.8592
# Epoch 35/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3768 - accuracy: 0.8843 - val_loss: 0.3824 - val_accuracy: 0.8923
# Epoch 36/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3904 - accuracy: 0.8793 - val_loss: 0.3614 - val_accuracy: 0.8966
# Epoch 37/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3778 - accuracy: 0.8881 - val_loss: 0.3736 - val_accuracy: 0.9025
# Epoch 38/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3710 - accuracy: 0.8932 - val_loss: 0.3765 - val_accuracy: 0.8798
# Epoch 39/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3666 - accuracy: 0.8944 - val_loss: 0.3596 - val_accuracy: 0.8993
# Epoch 40/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3756 - accuracy: 0.8867 - val_loss: 0.4174 - val_accuracy: 0.8690
# Epoch 41/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3812 - accuracy: 0.8775 - val_loss: 0.3575 - val_accuracy: 0.8966
# Epoch 42/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3732 - accuracy: 0.8933 - val_loss: 0.3939 - val_accuracy: 0.8809
# Epoch 43/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3838 - accuracy: 0.8827 - val_loss: 0.3569 - val_accuracy: 0.8982
# Epoch 44/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3636 - accuracy: 0.8937 - val_loss: 0.3604 - val_accuracy: 0.8847
# Epoch 45/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3642 - accuracy: 0.8910 - val_loss: 0.3919 - val_accuracy: 0.8825
# Epoch 46/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3791 - accuracy: 0.8832 - val_loss: 0.3767 - val_accuracy: 0.8738
# Epoch 47/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3695 - accuracy: 0.8896 - val_loss: 0.4460 - val_accuracy: 0.8598
# Epoch 48/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3786 - accuracy: 0.8858 - val_loss: 0.3544 - val_accuracy: 0.9015
# Epoch 49/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3640 - accuracy: 0.8957 - val_loss: 0.3923 - val_accuracy: 0.8803
# Epoch 50/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3707 - accuracy: 0.8928 - val_loss: 0.3498 - val_accuracy: 0.8950
# Epoch 51/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3673 - accuracy: 0.8914 - val_loss: 0.3813 - val_accuracy: 0.8809
# Epoch 52/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3739 - accuracy: 0.8883 - val_loss: 0.3716 - val_accuracy: 0.8831
# Epoch 53/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3744 - accuracy: 0.8850 - val_loss: 0.3615 - val_accuracy: 0.8852
# Epoch 54/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3648 - accuracy: 0.8926 - val_loss: 0.3670 - val_accuracy: 0.8863
# Epoch 55/500
# 174/174 [==============================] - 8s 46ms/step - loss: 0.3736 - accuracy: 0.8849 - val_loss: 0.3607 - val_accuracy: 0.8944
# Epoch 56/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3799 - accuracy: 0.8834 - val_loss: 0.3573 - val_accuracy: 0.8858
# Epoch 57/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3708 - accuracy: 0.8886 - val_loss: 0.3492 - val_accuracy: 0.9047
# Epoch 58/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3692 - accuracy: 0.8912 - val_loss: 0.3733 - val_accuracy: 0.8863
# Epoch 59/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3625 - accuracy: 0.8930 - val_loss: 0.3694 - val_accuracy: 0.8960
# Epoch 60/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3765 - accuracy: 0.8840 - val_loss: 0.4409 - val_accuracy: 0.8646
# Epoch 61/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3758 - accuracy: 0.8881 - val_loss: 0.3441 - val_accuracy: 0.9015
# Epoch 62/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3624 - accuracy: 0.8921 - val_loss: 0.3695 - val_accuracy: 0.8939
# Epoch 63/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3718 - accuracy: 0.8919 - val_loss: 0.3757 - val_accuracy: 0.8803
# Epoch 64/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3649 - accuracy: 0.8896 - val_loss: 0.3778 - val_accuracy: 0.8809
# Epoch 65/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3595 - accuracy: 0.8942 - val_loss: 0.3531 - val_accuracy: 0.9004
# Epoch 66/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3672 - accuracy: 0.8905 - val_loss: 0.3867 - val_accuracy: 0.8760
# Epoch 67/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3626 - accuracy: 0.8899 - val_loss: 0.3599 - val_accuracy: 0.9020
# Epoch 68/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3785 - accuracy: 0.8841 - val_loss: 0.3491 - val_accuracy: 0.9036
# Epoch 69/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3755 - accuracy: 0.8816 - val_loss: 0.3519 - val_accuracy: 0.9031
# Epoch 70/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3752 - accuracy: 0.8874 - val_loss: 0.3492 - val_accuracy: 0.8955
# Epoch 71/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3708 - accuracy: 0.8849 - val_loss: 0.3471 - val_accuracy: 0.9036
# Epoch 72/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3711 - accuracy: 0.8908 - val_loss: 0.3641 - val_accuracy: 0.8971
# Epoch 73/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3680 - accuracy: 0.8914 - val_loss: 0.3435 - val_accuracy: 0.9042
# Epoch 74/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3761 - accuracy: 0.8865 - val_loss: 0.3800 - val_accuracy: 0.8874
# Epoch 75/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3772 - accuracy: 0.8840 - val_loss: 0.3799 - val_accuracy: 0.8766
# Epoch 76/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3667 - accuracy: 0.8928 - val_loss: 0.3700 - val_accuracy: 0.8901
# Epoch 77/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3624 - accuracy: 0.8984 - val_loss: 0.3598 - val_accuracy: 0.8955
# Epoch 78/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3754 - accuracy: 0.8868 - val_loss: 0.3579 - val_accuracy: 0.9047
# Epoch 79/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3710 - accuracy: 0.8897 - val_loss: 0.4316 - val_accuracy: 0.8549
# Epoch 80/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3808 - accuracy: 0.8832 - val_loss: 0.3644 - val_accuracy: 0.8858
# Epoch 81/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3693 - accuracy: 0.8874 - val_loss: 0.4004 - val_accuracy: 0.8755
# Epoch 82/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3690 - accuracy: 0.8921 - val_loss: 0.3978 - val_accuracy: 0.8695
# Epoch 83/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3665 - accuracy: 0.8970 - val_loss: 0.3570 - val_accuracy: 0.8950
# Epoch 84/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3669 - accuracy: 0.8935 - val_loss: 0.3588 - val_accuracy: 0.8939
# Epoch 85/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3886 - accuracy: 0.8793 - val_loss: 0.3492 - val_accuracy: 0.9085
# Epoch 86/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3708 - accuracy: 0.8872 - val_loss: 0.4001 - val_accuracy: 0.8733
# Epoch 87/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3739 - accuracy: 0.8822 - val_loss: 0.3559 - val_accuracy: 0.9015
# Epoch 88/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3793 - accuracy: 0.8838 - val_loss: 0.4308 - val_accuracy: 0.8636
# Epoch 89/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3816 - accuracy: 0.8827 - val_loss: 0.4302 - val_accuracy: 0.8711
# Epoch 90/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3701 - accuracy: 0.8888 - val_loss: 0.3505 - val_accuracy: 0.8988
# Epoch 91/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3638 - accuracy: 0.8914 - val_loss: 0.3696 - val_accuracy: 0.8820
# Epoch 92/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3543 - accuracy: 0.8933 - val_loss: 0.3440 - val_accuracy: 0.8982
# Epoch 93/500
# 174/174 [==============================] - 6s 33ms/step - loss: 0.3861 - accuracy: 0.8778 - val_loss: 0.4369 - val_accuracy: 0.8365
# Epoch 94/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3738 - accuracy: 0.8836 - val_loss: 0.3791 - val_accuracy: 0.8820
# Epoch 95/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3629 - accuracy: 0.8935 - val_loss: 0.3839 - val_accuracy: 0.8744
# Epoch 96/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3625 - accuracy: 0.8953 - val_loss: 0.3480 - val_accuracy: 0.9025
# Epoch 97/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3597 - accuracy: 0.8944 - val_loss: 0.3532 - val_accuracy: 0.9004
# Epoch 98/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3833 - accuracy: 0.8780 - val_loss: 0.3791 - val_accuracy: 0.8896
# Epoch 99/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3736 - accuracy: 0.8876 - val_loss: 0.3478 - val_accuracy: 0.9042
# Epoch 100/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3593 - accuracy: 0.8941 - val_loss: 0.3460 - val_accuracy: 0.9058
# Epoch 101/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3646 - accuracy: 0.8935 - val_loss: 0.3466 - val_accuracy: 0.8993
# Epoch 102/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3702 - accuracy: 0.8868 - val_loss: 0.3444 - val_accuracy: 0.8988
# Epoch 103/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3715 - accuracy: 0.8912 - val_loss: 0.3925 - val_accuracy: 0.8668
# Epoch 104/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3620 - accuracy: 0.8923 - val_loss: 0.4866 - val_accuracy: 0.8387
# Epoch 105/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3820 - accuracy: 0.8809 - val_loss: 0.5296 - val_accuracy: 0.8278
# Epoch 106/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3677 - accuracy: 0.8870 - val_loss: 0.3583 - val_accuracy: 0.9015
# Epoch 107/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3566 - accuracy: 0.8971 - val_loss: 0.3469 - val_accuracy: 0.9009
# Epoch 108/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3565 - accuracy: 0.8928 - val_loss: 0.3524 - val_accuracy: 0.8912
# Epoch 109/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3638 - accuracy: 0.8905 - val_loss: 0.3454 - val_accuracy: 0.8971
# Epoch 110/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3586 - accuracy: 0.8917 - val_loss: 0.3822 - val_accuracy: 0.8776
# Epoch 111/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3704 - accuracy: 0.8885 - val_loss: 0.3736 - val_accuracy: 0.8847
# Epoch 112/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3570 - accuracy: 0.8926 - val_loss: 0.3485 - val_accuracy: 0.8998
# Epoch 113/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3676 - accuracy: 0.8901 - val_loss: 0.4163 - val_accuracy: 0.8663
# Epoch 114/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3890 - accuracy: 0.8796 - val_loss: 0.3513 - val_accuracy: 0.9025
# Epoch 115/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3807 - accuracy: 0.8827 - val_loss: 0.3703 - val_accuracy: 0.8950
# Epoch 116/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3640 - accuracy: 0.8917 - val_loss: 0.3450 - val_accuracy: 0.9047
# Epoch 117/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3640 - accuracy: 0.8905 - val_loss: 0.3539 - val_accuracy: 0.8944
# Epoch 118/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3644 - accuracy: 0.8870 - val_loss: 0.3525 - val_accuracy: 0.8998
# Epoch 119/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3663 - accuracy: 0.8896 - val_loss: 0.3549 - val_accuracy: 0.8944
# Epoch 120/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3753 - accuracy: 0.8843 - val_loss: 0.3572 - val_accuracy: 0.8944
# Epoch 121/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3577 - accuracy: 0.8973 - val_loss: 0.3448 - val_accuracy: 0.9063
# Epoch 122/500
# 174/174 [==============================] - 6s 33ms/step - loss: 0.3615 - accuracy: 0.8914 - val_loss: 0.3400 - val_accuracy: 0.9025
# Epoch 123/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3585 - accuracy: 0.8959 - val_loss: 0.4338 - val_accuracy: 0.8430
# Epoch 124/500
# 174/174 [==============================] - 6s 33ms/step - loss: 0.3795 - accuracy: 0.8818 - val_loss: 0.4483 - val_accuracy: 0.8495
# Epoch 125/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3628 - accuracy: 0.8912 - val_loss: 0.3543 - val_accuracy: 0.8960
# Epoch 126/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3724 - accuracy: 0.8838 - val_loss: 0.3608 - val_accuracy: 0.8977
# Epoch 127/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3658 - accuracy: 0.8919 - val_loss: 0.3603 - val_accuracy: 0.8809
# Epoch 128/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3805 - accuracy: 0.8841 - val_loss: 0.4508 - val_accuracy: 0.8549
# Epoch 129/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3660 - accuracy: 0.8896 - val_loss: 0.3705 - val_accuracy: 0.8858
# Epoch 130/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3660 - accuracy: 0.8874 - val_loss: 0.4041 - val_accuracy: 0.8646
# Epoch 131/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3683 - accuracy: 0.8879 - val_loss: 0.3429 - val_accuracy: 0.9036
# Epoch 132/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3648 - accuracy: 0.8883 - val_loss: 0.3723 - val_accuracy: 0.8928
# Epoch 133/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3798 - accuracy: 0.8802 - val_loss: 0.3707 - val_accuracy: 0.8831
# Epoch 134/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3622 - accuracy: 0.8924 - val_loss: 0.3492 - val_accuracy: 0.8977
# Epoch 135/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3596 - accuracy: 0.8879 - val_loss: 0.3565 - val_accuracy: 0.8944
# Epoch 136/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.4021 - accuracy: 0.8699 - val_loss: 0.3906 - val_accuracy: 0.8787
# Epoch 137/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3607 - accuracy: 0.8923 - val_loss: 0.3987 - val_accuracy: 0.8771
# Epoch 138/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3842 - accuracy: 0.8840 - val_loss: 0.3795 - val_accuracy: 0.8771
# Epoch 139/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3702 - accuracy: 0.8870 - val_loss: 0.3592 - val_accuracy: 0.8896
# Epoch 140/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3684 - accuracy: 0.8863 - val_loss: 0.3645 - val_accuracy: 0.8809
# Epoch 141/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3759 - accuracy: 0.8861 - val_loss: 0.3491 - val_accuracy: 0.8977
# Epoch 142/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3601 - accuracy: 0.8899 - val_loss: 0.3634 - val_accuracy: 0.8960
# Epoch 143/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3760 - accuracy: 0.8849 - val_loss: 0.4018 - val_accuracy: 0.8722
# Epoch 144/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3554 - accuracy: 0.8935 - val_loss: 0.3676 - val_accuracy: 0.8955
# Epoch 145/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3661 - accuracy: 0.8881 - val_loss: 0.3666 - val_accuracy: 0.8971
# Epoch 146/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3735 - accuracy: 0.8780 - val_loss: 0.4374 - val_accuracy: 0.8581
# Epoch 147/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3699 - accuracy: 0.8885 - val_loss: 0.3818 - val_accuracy: 0.8847
# Epoch 148/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3709 - accuracy: 0.8861 - val_loss: 0.3517 - val_accuracy: 0.9009
# Epoch 149/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3780 - accuracy: 0.8865 - val_loss: 0.3771 - val_accuracy: 0.8971
# Epoch 150/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3584 - accuracy: 0.8950 - val_loss: 0.3480 - val_accuracy: 0.9015
# Epoch 151/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3670 - accuracy: 0.8939 - val_loss: 0.3581 - val_accuracy: 0.8923
# Epoch 152/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3592 - accuracy: 0.8930 - val_loss: 0.3451 - val_accuracy: 0.9004
# Epoch 153/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3773 - accuracy: 0.8822 - val_loss: 0.3808 - val_accuracy: 0.8858
# Epoch 154/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3672 - accuracy: 0.8885 - val_loss: 0.3604 - val_accuracy: 0.8906
# Epoch 155/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3775 - accuracy: 0.8775 - val_loss: 0.3476 - val_accuracy: 0.9020
# Epoch 156/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3640 - accuracy: 0.8924 - val_loss: 0.3463 - val_accuracy: 0.9009
# Epoch 157/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3715 - accuracy: 0.8888 - val_loss: 0.3661 - val_accuracy: 0.8944
# Epoch 158/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3632 - accuracy: 0.8932 - val_loss: 0.3791 - val_accuracy: 0.8863
# Epoch 159/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3563 - accuracy: 0.8946 - val_loss: 0.3506 - val_accuracy: 0.8982
# Epoch 160/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3657 - accuracy: 0.8892 - val_loss: 0.3627 - val_accuracy: 0.8858
# Epoch 161/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3685 - accuracy: 0.8879 - val_loss: 0.3751 - val_accuracy: 0.8798
# Epoch 162/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3728 - accuracy: 0.8906 - val_loss: 0.3588 - val_accuracy: 0.8906
# Epoch 163/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3611 - accuracy: 0.8910 - val_loss: 0.3752 - val_accuracy: 0.8858
# Epoch 164/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3561 - accuracy: 0.8919 - val_loss: 0.3812 - val_accuracy: 0.8896
# Epoch 165/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3699 - accuracy: 0.8890 - val_loss: 0.3514 - val_accuracy: 0.9009
# Epoch 166/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3686 - accuracy: 0.8896 - val_loss: 0.3599 - val_accuracy: 0.8917
# Epoch 167/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3640 - accuracy: 0.8890 - val_loss: 0.3476 - val_accuracy: 0.8917
# Epoch 168/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3661 - accuracy: 0.8901 - val_loss: 0.3744 - val_accuracy: 0.8798
# Epoch 169/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3656 - accuracy: 0.8872 - val_loss: 0.3685 - val_accuracy: 0.8868
# Epoch 170/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3802 - accuracy: 0.8803 - val_loss: 0.3601 - val_accuracy: 0.8928
# Epoch 171/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3605 - accuracy: 0.8962 - val_loss: 0.4138 - val_accuracy: 0.8457
# Epoch 172/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3683 - accuracy: 0.8919 - val_loss: 0.3740 - val_accuracy: 0.8841
# Epoch 173/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3768 - accuracy: 0.8859 - val_loss: 0.3622 - val_accuracy: 0.9009
# Epoch 174/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3752 - accuracy: 0.8865 - val_loss: 0.4321 - val_accuracy: 0.8387
# Epoch 175/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3666 - accuracy: 0.8908 - val_loss: 0.3465 - val_accuracy: 0.8993
# Epoch 176/500
# 174/174 [==============================] - 8s 45ms/step - loss: 0.3687 - accuracy: 0.8865 - val_loss: 0.3451 - val_accuracy: 0.9025
# Epoch 177/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3666 - accuracy: 0.8883 - val_loss: 0.4129 - val_accuracy: 0.8581
# Epoch 178/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3680 - accuracy: 0.8881 - val_loss: 0.3491 - val_accuracy: 0.8901
# Epoch 179/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3634 - accuracy: 0.8881 - val_loss: 0.3680 - val_accuracy: 0.8890
# Epoch 180/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3656 - accuracy: 0.8859 - val_loss: 0.3622 - val_accuracy: 0.8890
# Epoch 181/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3628 - accuracy: 0.8894 - val_loss: 0.3507 - val_accuracy: 0.8982
# Epoch 182/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3624 - accuracy: 0.8879 - val_loss: 0.3544 - val_accuracy: 0.8901
# Epoch 183/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3643 - accuracy: 0.8923 - val_loss: 0.3711 - val_accuracy: 0.8966
# Epoch 184/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3720 - accuracy: 0.8874 - val_loss: 0.4394 - val_accuracy: 0.8619
# Epoch 185/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.4189 - accuracy: 0.8616 - val_loss: 0.4145 - val_accuracy: 0.8738
# Epoch 186/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3613 - accuracy: 0.8914 - val_loss: 0.3681 - val_accuracy: 0.8836
# Epoch 187/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3665 - accuracy: 0.8885 - val_loss: 0.3824 - val_accuracy: 0.8912
# Epoch 188/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3683 - accuracy: 0.8859 - val_loss: 0.3500 - val_accuracy: 0.8998
# Epoch 189/500
# 174/174 [==============================] - 6s 34ms/step - loss: 0.3699 - accuracy: 0.8883 - val_loss: 0.3470 - val_accuracy: 0.8971
# Epoch 190/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3783 - accuracy: 0.8836 - val_loss: 0.3750 - val_accuracy: 0.8841
# Epoch 191/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3697 - accuracy: 0.8861 - val_loss: 0.4139 - val_accuracy: 0.8560
# Epoch 192/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3811 - accuracy: 0.8798 - val_loss: 0.3511 - val_accuracy: 0.8960
# Epoch 193/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3612 - accuracy: 0.8935 - val_loss: 0.4054 - val_accuracy: 0.8701
# Epoch 194/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3736 - accuracy: 0.8843 - val_loss: 0.3930 - val_accuracy: 0.8782
# Epoch 195/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3692 - accuracy: 0.8901 - val_loss: 0.4352 - val_accuracy: 0.8441
# Epoch 196/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3780 - accuracy: 0.8843 - val_loss: 0.3534 - val_accuracy: 0.8901
# Epoch 197/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3680 - accuracy: 0.8901 - val_loss: 0.3456 - val_accuracy: 0.9025
# Epoch 198/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3594 - accuracy: 0.8957 - val_loss: 0.3462 - val_accuracy: 0.9074
# Epoch 199/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3712 - accuracy: 0.8874 - val_loss: 0.3589 - val_accuracy: 0.8836
# Epoch 200/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3669 - accuracy: 0.8886 - val_loss: 0.3817 - val_accuracy: 0.8787
# Epoch 201/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3775 - accuracy: 0.8834 - val_loss: 0.4066 - val_accuracy: 0.8744
# Epoch 202/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3643 - accuracy: 0.8933 - val_loss: 0.3661 - val_accuracy: 0.8831
# Epoch 203/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3824 - accuracy: 0.8807 - val_loss: 0.3557 - val_accuracy: 0.8950
# Epoch 204/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3625 - accuracy: 0.8905 - val_loss: 0.4176 - val_accuracy: 0.8511
# Epoch 205/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3812 - accuracy: 0.8803 - val_loss: 0.3516 - val_accuracy: 0.9015
# Epoch 206/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3648 - accuracy: 0.8923 - val_loss: 0.3754 - val_accuracy: 0.8841
# Epoch 207/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3715 - accuracy: 0.8888 - val_loss: 0.4188 - val_accuracy: 0.8581
# Epoch 208/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3682 - accuracy: 0.8928 - val_loss: 0.3748 - val_accuracy: 0.8825
# Epoch 209/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3658 - accuracy: 0.8924 - val_loss: 0.3630 - val_accuracy: 0.8852
# Epoch 210/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3750 - accuracy: 0.8865 - val_loss: 0.3646 - val_accuracy: 0.8863
# Epoch 211/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3658 - accuracy: 0.8879 - val_loss: 0.3833 - val_accuracy: 0.8820
# Epoch 212/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3685 - accuracy: 0.8867 - val_loss: 0.3502 - val_accuracy: 0.9042
# Epoch 213/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3739 - accuracy: 0.8886 - val_loss: 0.4004 - val_accuracy: 0.8684
# Epoch 214/500
# 174/174 [==============================] - 8s 43ms/step - loss: 0.3671 - accuracy: 0.8932 - val_loss: 0.4375 - val_accuracy: 0.8533
# Epoch 215/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3740 - accuracy: 0.8865 - val_loss: 0.3613 - val_accuracy: 0.9009
# Epoch 216/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3629 - accuracy: 0.8944 - val_loss: 0.4094 - val_accuracy: 0.8782
# Epoch 217/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3652 - accuracy: 0.8897 - val_loss: 0.3609 - val_accuracy: 0.8906
# Epoch 218/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3634 - accuracy: 0.8899 - val_loss: 0.3526 - val_accuracy: 0.9020
# Epoch 219/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3658 - accuracy: 0.8912 - val_loss: 0.3595 - val_accuracy: 0.8858
# Epoch 220/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3759 - accuracy: 0.8850 - val_loss: 0.3548 - val_accuracy: 0.8993
# Epoch 221/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3720 - accuracy: 0.8854 - val_loss: 0.3453 - val_accuracy: 0.9074
# Epoch 222/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3874 - accuracy: 0.8812 - val_loss: 0.3596 - val_accuracy: 0.8977
# Epoch 223/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3634 - accuracy: 0.8946 - val_loss: 0.4287 - val_accuracy: 0.8609
# Epoch 224/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3823 - accuracy: 0.8807 - val_loss: 0.3612 - val_accuracy: 0.8955
# Epoch 225/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3599 - accuracy: 0.8933 - val_loss: 0.3496 - val_accuracy: 0.8944
# Epoch 226/500
# 174/174 [==============================] - 8s 43ms/step - loss: 0.3726 - accuracy: 0.8888 - val_loss: 0.3454 - val_accuracy: 0.8993
# Epoch 227/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3681 - accuracy: 0.8870 - val_loss: 0.3565 - val_accuracy: 0.9015
# Epoch 228/500
# 174/174 [==============================] - 8s 44ms/step - loss: 0.3694 - accuracy: 0.8886 - val_loss: 0.3512 - val_accuracy: 0.9009
# Epoch 229/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3649 - accuracy: 0.8908 - val_loss: 0.3768 - val_accuracy: 0.8831
# Epoch 230/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3691 - accuracy: 0.8924 - val_loss: 0.3462 - val_accuracy: 0.9031
# Epoch 231/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3773 - accuracy: 0.8832 - val_loss: 0.3505 - val_accuracy: 0.8906
# Epoch 232/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3791 - accuracy: 0.8825 - val_loss: 0.3485 - val_accuracy: 0.9020
# Epoch 233/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3688 - accuracy: 0.8881 - val_loss: 0.4130 - val_accuracy: 0.8722
# Epoch 234/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3670 - accuracy: 0.8915 - val_loss: 0.3480 - val_accuracy: 0.9020
# Epoch 235/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3676 - accuracy: 0.8850 - val_loss: 0.3699 - val_accuracy: 0.8868
# Epoch 236/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3611 - accuracy: 0.8914 - val_loss: 0.5164 - val_accuracy: 0.8300
# Epoch 237/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3802 - accuracy: 0.8809 - val_loss: 0.4694 - val_accuracy: 0.8251
# Epoch 238/500
# 174/174 [==============================] - 7s 43ms/step - loss: 0.3675 - accuracy: 0.8877 - val_loss: 0.4569 - val_accuracy: 0.8240
# Epoch 239/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3844 - accuracy: 0.8803 - val_loss: 0.3939 - val_accuracy: 0.8766
# Epoch 240/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3740 - accuracy: 0.8872 - val_loss: 0.3523 - val_accuracy: 0.9069
# Epoch 241/500
# 174/174 [==============================] - 7s 37ms/step - loss: 0.3661 - accuracy: 0.8946 - val_loss: 0.3566 - val_accuracy: 0.8977
# Epoch 242/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3690 - accuracy: 0.8903 - val_loss: 0.3824 - val_accuracy: 0.8836
# Epoch 243/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3558 - accuracy: 0.8944 - val_loss: 0.3649 - val_accuracy: 0.8912
# Epoch 244/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3646 - accuracy: 0.8870 - val_loss: 0.3474 - val_accuracy: 0.8944
# Epoch 245/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3658 - accuracy: 0.8919 - val_loss: 0.3619 - val_accuracy: 0.8874
# Epoch 246/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3598 - accuracy: 0.8930 - val_loss: 0.3515 - val_accuracy: 0.8917
# Epoch 247/500
# 174/174 [==============================] - 7s 43ms/step - loss: 0.3502 - accuracy: 0.8957 - val_loss: 0.3500 - val_accuracy: 0.8982
# Epoch 248/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3643 - accuracy: 0.8912 - val_loss: 0.4854 - val_accuracy: 0.8062
# Epoch 249/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3753 - accuracy: 0.8874 - val_loss: 0.3880 - val_accuracy: 0.8766
# Epoch 250/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3648 - accuracy: 0.8896 - val_loss: 0.4895 - val_accuracy: 0.8419
# Epoch 251/500
# 174/174 [==============================] - 8s 49ms/step - loss: 0.3653 - accuracy: 0.8890 - val_loss: 0.5456 - val_accuracy: 0.8251
# Epoch 252/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3830 - accuracy: 0.8794 - val_loss: 0.3504 - val_accuracy: 0.8928
# Epoch 253/500
# 174/174 [==============================] - 8s 44ms/step - loss: 0.3683 - accuracy: 0.8912 - val_loss: 0.3522 - val_accuracy: 0.8944
# Epoch 254/500
# 174/174 [==============================] - 7s 37ms/step - loss: 0.3747 - accuracy: 0.8852 - val_loss: 0.3668 - val_accuracy: 0.8960
# Epoch 255/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3612 - accuracy: 0.8910 - val_loss: 0.3577 - val_accuracy: 0.8906
# Epoch 256/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3637 - accuracy: 0.8932 - val_loss: 0.3892 - val_accuracy: 0.8684
# Epoch 257/500
# 174/174 [==============================] - 7s 43ms/step - loss: 0.3737 - accuracy: 0.8885 - val_loss: 0.3553 - val_accuracy: 0.8966
# Epoch 258/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3647 - accuracy: 0.8896 - val_loss: 0.3484 - val_accuracy: 0.9058
# Epoch 259/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3599 - accuracy: 0.8868 - val_loss: 0.3474 - val_accuracy: 0.8874
# Epoch 260/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3679 - accuracy: 0.8883 - val_loss: 0.3486 - val_accuracy: 0.8982
# Epoch 261/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3757 - accuracy: 0.8874 - val_loss: 0.3546 - val_accuracy: 0.8971
# Epoch 262/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3653 - accuracy: 0.8894 - val_loss: 0.3413 - val_accuracy: 0.9009
# Epoch 263/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3615 - accuracy: 0.8892 - val_loss: 0.3782 - val_accuracy: 0.8933
# Epoch 264/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3887 - accuracy: 0.8773 - val_loss: 0.3547 - val_accuracy: 0.8977
# Epoch 265/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3640 - accuracy: 0.8908 - val_loss: 0.3424 - val_accuracy: 0.9020
# Epoch 266/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3752 - accuracy: 0.8823 - val_loss: 0.3773 - val_accuracy: 0.8896
# Epoch 267/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3687 - accuracy: 0.8896 - val_loss: 0.3659 - val_accuracy: 0.8852
# Epoch 268/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3807 - accuracy: 0.8812 - val_loss: 0.3896 - val_accuracy: 0.8803
# Epoch 269/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3718 - accuracy: 0.8852 - val_loss: 0.3526 - val_accuracy: 0.8971
# Epoch 270/500
# 174/174 [==============================] - 7s 37ms/step - loss: 0.3594 - accuracy: 0.8962 - val_loss: 0.5360 - val_accuracy: 0.8295
# Epoch 271/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3619 - accuracy: 0.8924 - val_loss: 0.3452 - val_accuracy: 0.8982
# Epoch 272/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3612 - accuracy: 0.8971 - val_loss: 0.3679 - val_accuracy: 0.8917
# Epoch 273/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3670 - accuracy: 0.8876 - val_loss: 0.3608 - val_accuracy: 0.8955
# Epoch 274/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3723 - accuracy: 0.8847 - val_loss: 0.3839 - val_accuracy: 0.8868
# Epoch 275/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3610 - accuracy: 0.8932 - val_loss: 0.3431 - val_accuracy: 0.9009
# Epoch 276/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3645 - accuracy: 0.8924 - val_loss: 0.3506 - val_accuracy: 0.8993
# Epoch 277/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3653 - accuracy: 0.8885 - val_loss: 0.3566 - val_accuracy: 0.8988
# Epoch 278/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3831 - accuracy: 0.8831 - val_loss: 0.3621 - val_accuracy: 0.8858
# Epoch 279/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3616 - accuracy: 0.8935 - val_loss: 0.3422 - val_accuracy: 0.8977
# Epoch 280/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3686 - accuracy: 0.8915 - val_loss: 0.3684 - val_accuracy: 0.8841
# Epoch 281/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3723 - accuracy: 0.8879 - val_loss: 0.4163 - val_accuracy: 0.8728
# Epoch 282/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3753 - accuracy: 0.8874 - val_loss: 0.3579 - val_accuracy: 0.8960
# Epoch 283/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3531 - accuracy: 0.8973 - val_loss: 0.4652 - val_accuracy: 0.8479
# Epoch 284/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3650 - accuracy: 0.8914 - val_loss: 0.3493 - val_accuracy: 0.9020
# Epoch 285/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3603 - accuracy: 0.8926 - val_loss: 0.3948 - val_accuracy: 0.8809
# Epoch 286/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3627 - accuracy: 0.8896 - val_loss: 0.3973 - val_accuracy: 0.8771
# Epoch 287/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3755 - accuracy: 0.8809 - val_loss: 0.4905 - val_accuracy: 0.8208
# Epoch 288/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3642 - accuracy: 0.8912 - val_loss: 0.3757 - val_accuracy: 0.8966
# Epoch 289/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3611 - accuracy: 0.8935 - val_loss: 0.3928 - val_accuracy: 0.8782
# Epoch 290/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3804 - accuracy: 0.8822 - val_loss: 0.3486 - val_accuracy: 0.9009
# Epoch 291/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3663 - accuracy: 0.8919 - val_loss: 0.3645 - val_accuracy: 0.8960
# Epoch 292/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3603 - accuracy: 0.8926 - val_loss: 0.3647 - val_accuracy: 0.8933
# Epoch 293/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3633 - accuracy: 0.8903 - val_loss: 0.3650 - val_accuracy: 0.8933
# Epoch 294/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3627 - accuracy: 0.8883 - val_loss: 0.4173 - val_accuracy: 0.8636
# Epoch 295/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3589 - accuracy: 0.8924 - val_loss: 0.4553 - val_accuracy: 0.8728
# Epoch 296/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3875 - accuracy: 0.8850 - val_loss: 0.3498 - val_accuracy: 0.9069
# Epoch 297/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3639 - accuracy: 0.8905 - val_loss: 0.4928 - val_accuracy: 0.8067
# Epoch 298/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3743 - accuracy: 0.8820 - val_loss: 0.3545 - val_accuracy: 0.8993
# Epoch 299/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3632 - accuracy: 0.8910 - val_loss: 0.3389 - val_accuracy: 0.9015
# Epoch 300/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3577 - accuracy: 0.8942 - val_loss: 0.4983 - val_accuracy: 0.8430
# Epoch 301/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3724 - accuracy: 0.8859 - val_loss: 0.3486 - val_accuracy: 0.8955
# Epoch 302/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3611 - accuracy: 0.8919 - val_loss: 0.4353 - val_accuracy: 0.8625
# Epoch 303/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3678 - accuracy: 0.8885 - val_loss: 0.3935 - val_accuracy: 0.8701
# Epoch 304/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3698 - accuracy: 0.8896 - val_loss: 0.6354 - val_accuracy: 0.7937
# Epoch 305/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3884 - accuracy: 0.8796 - val_loss: 0.3572 - val_accuracy: 0.8923
# Epoch 306/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3649 - accuracy: 0.8971 - val_loss: 0.3548 - val_accuracy: 0.8955
# Epoch 307/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3777 - accuracy: 0.8820 - val_loss: 0.3847 - val_accuracy: 0.8820
# Epoch 308/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3723 - accuracy: 0.8854 - val_loss: 0.3580 - val_accuracy: 0.8896
# Epoch 309/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3704 - accuracy: 0.8861 - val_loss: 0.3541 - val_accuracy: 0.8993
# Epoch 310/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3642 - accuracy: 0.8917 - val_loss: 0.3774 - val_accuracy: 0.8923
# Epoch 311/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3587 - accuracy: 0.8914 - val_loss: 0.3548 - val_accuracy: 0.8917
# Epoch 312/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3682 - accuracy: 0.8896 - val_loss: 0.3562 - val_accuracy: 0.8966
# Epoch 313/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3739 - accuracy: 0.8879 - val_loss: 0.3710 - val_accuracy: 0.8874
# Epoch 314/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3668 - accuracy: 0.8906 - val_loss: 0.4172 - val_accuracy: 0.8728
# Epoch 315/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3679 - accuracy: 0.8858 - val_loss: 0.3500 - val_accuracy: 0.9047
# Epoch 316/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3684 - accuracy: 0.8903 - val_loss: 0.3539 - val_accuracy: 0.8982
# Epoch 317/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3909 - accuracy: 0.8789 - val_loss: 0.3536 - val_accuracy: 0.9058
# Epoch 318/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3705 - accuracy: 0.8888 - val_loss: 0.3488 - val_accuracy: 0.9015
# Epoch 319/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3740 - accuracy: 0.8840 - val_loss: 0.3542 - val_accuracy: 0.8939
# Epoch 320/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3665 - accuracy: 0.8899 - val_loss: 0.3630 - val_accuracy: 0.8890
# Epoch 321/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3734 - accuracy: 0.8849 - val_loss: 0.3483 - val_accuracy: 0.9020
# Epoch 322/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3632 - accuracy: 0.8973 - val_loss: 0.3457 - val_accuracy: 0.9031
# Epoch 323/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3621 - accuracy: 0.8926 - val_loss: 0.3470 - val_accuracy: 0.9036
# Epoch 324/500
# 174/174 [==============================] - 8s 43ms/step - loss: 0.3656 - accuracy: 0.8919 - val_loss: 0.4367 - val_accuracy: 0.8560
# Epoch 325/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3642 - accuracy: 0.8951 - val_loss: 0.3565 - val_accuracy: 0.8944
# Epoch 326/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3613 - accuracy: 0.8941 - val_loss: 0.3498 - val_accuracy: 0.9063
# Epoch 327/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3702 - accuracy: 0.8872 - val_loss: 0.3697 - val_accuracy: 0.8885
# Epoch 328/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3733 - accuracy: 0.8849 - val_loss: 0.3553 - val_accuracy: 0.9042
# Epoch 329/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3587 - accuracy: 0.8939 - val_loss: 0.3686 - val_accuracy: 0.8847
# Epoch 330/500
# ...
# Epoch 392/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3697 - accuracy: 0.8854 - val_loss: 0.3465 - val_accuracy: 0.9069
# Epoch 393/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3646 - accuracy: 0.8876 - val_loss: 0.3655 - val_accuracy: 0.8787
# Epoch 394/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3709 - accuracy: 0.8863 - val_loss: 0.3505 - val_accuracy: 0.8971
# Epoch 395/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3717 - accuracy: 0.8843 - val_loss: 0.3512 - val_accuracy: 0.8993
# Epoch 396/500
# 174/174 [==============================] - 7s 43ms/step - loss: 0.3631 - accuracy: 0.8901 - val_loss: 0.4278 - val_accuracy: 0.8641
# Epoch 397/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3898 - accuracy: 0.8758 - val_loss: 0.3538 - val_accuracy: 0.8966
# Epoch 398/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3594 - accuracy: 0.8946 - val_loss: 0.3676 - val_accuracy: 0.8928
# Epoch 399/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3631 - accuracy: 0.8932 - val_loss: 0.3485 - val_accuracy: 0.8993
# Epoch 400/500
# 174/174 [==============================] - 7s 43ms/step - loss: 0.3871 - accuracy: 0.8789 - val_loss: 0.3532 - val_accuracy: 0.8993
# Epoch 401/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3589 - accuracy: 0.8941 - val_loss: 0.4346 - val_accuracy: 0.8365
# Epoch 402/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3658 - accuracy: 0.8865 - val_loss: 0.3564 - val_accuracy: 0.8928
# Epoch 403/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3605 - accuracy: 0.8932 - val_loss: 0.4308 - val_accuracy: 0.8338
# Epoch 404/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3636 - accuracy: 0.8910 - val_loss: 0.3554 - val_accuracy: 0.8955
# Epoch 405/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3768 - accuracy: 0.8818 - val_loss: 0.3569 - val_accuracy: 0.9004
# Epoch 406/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3587 - accuracy: 0.8935 - val_loss: 0.3826 - val_accuracy: 0.8701
# Epoch 407/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3642 - accuracy: 0.8914 - val_loss: 0.3658 - val_accuracy: 0.8885
# Epoch 408/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3681 - accuracy: 0.8867 - val_loss: 0.4422 - val_accuracy: 0.8581
# Epoch 409/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3672 - accuracy: 0.8897 - val_loss: 0.3456 - val_accuracy: 0.9074
# Epoch 410/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3687 - accuracy: 0.8872 - val_loss: 0.3630 - val_accuracy: 0.9015
# Epoch 411/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3648 - accuracy: 0.8932 - val_loss: 0.3862 - val_accuracy: 0.8766
# Epoch 412/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3635 - accuracy: 0.8912 - val_loss: 0.4570 - val_accuracy: 0.8457
# Epoch 413/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3821 - accuracy: 0.8789 - val_loss: 0.4018 - val_accuracy: 0.8749
# Epoch 414/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3732 - accuracy: 0.8896 - val_loss: 0.3479 - val_accuracy: 0.9053
# Epoch 415/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3854 - accuracy: 0.8836 - val_loss: 0.3561 - val_accuracy: 0.9031
# Epoch 416/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3828 - accuracy: 0.8822 - val_loss: 0.3607 - val_accuracy: 0.9020
# Epoch 417/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3745 - accuracy: 0.8872 - val_loss: 0.3690 - val_accuracy: 0.8841
# Epoch 418/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3631 - accuracy: 0.8939 - val_loss: 0.3523 - val_accuracy: 0.8971
# Epoch 419/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3671 - accuracy: 0.8899 - val_loss: 0.3460 - val_accuracy: 0.9085
# Epoch 420/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3602 - accuracy: 0.8930 - val_loss: 0.3978 - val_accuracy: 0.8809
# Epoch 421/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3674 - accuracy: 0.8910 - val_loss: 0.3952 - val_accuracy: 0.8803
# Epoch 422/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3672 - accuracy: 0.8921 - val_loss: 0.3704 - val_accuracy: 0.8847
# Epoch 423/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3644 - accuracy: 0.8899 - val_loss: 0.3524 - val_accuracy: 0.8977
# Epoch 424/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3629 - accuracy: 0.8879 - val_loss: 0.3549 - val_accuracy: 0.8998
# Epoch 425/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3598 - accuracy: 0.8921 - val_loss: 0.4380 - val_accuracy: 0.8701
# Epoch 426/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3805 - accuracy: 0.8840 - val_loss: 0.3491 - val_accuracy: 0.8982
# Epoch 427/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3725 - accuracy: 0.8876 - val_loss: 0.4309 - val_accuracy: 0.8646
# Epoch 428/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3625 - accuracy: 0.8899 - val_loss: 0.3442 - val_accuracy: 0.9015
# Epoch 429/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3660 - accuracy: 0.8885 - val_loss: 0.3612 - val_accuracy: 0.8874
# Epoch 430/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3647 - accuracy: 0.8914 - val_loss: 0.3668 - val_accuracy: 0.8912
# Epoch 431/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3656 - accuracy: 0.8870 - val_loss: 0.3858 - val_accuracy: 0.8776
# Epoch 432/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3672 - accuracy: 0.8874 - val_loss: 0.3544 - val_accuracy: 0.8977
# Epoch 433/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3729 - accuracy: 0.8868 - val_loss: 0.3771 - val_accuracy: 0.8852
# Epoch 434/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3853 - accuracy: 0.8814 - val_loss: 0.3695 - val_accuracy: 0.8890
# Epoch 435/500
# 174/174 [==============================] - 7s 39ms/step - loss: 0.3725 - accuracy: 0.8843 - val_loss: 0.3740 - val_accuracy: 0.8809
# Epoch 436/500
# 174/174 [==============================] - 7s 38ms/step - loss: 0.3615 - accuracy: 0.8923 - val_loss: 0.3987 - val_accuracy: 0.8701
# Epoch 437/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3809 - accuracy: 0.8825 - val_loss: 0.3534 - val_accuracy: 0.8879
# Epoch 438/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3665 - accuracy: 0.8919 - val_loss: 0.3509 - val_accuracy: 0.8960
# Epoch 439/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3723 - accuracy: 0.8861 - val_loss: 0.3496 - val_accuracy: 0.9015
# Epoch 440/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3762 - accuracy: 0.8879 - val_loss: 0.3514 - val_accuracy: 0.9009
# Epoch 441/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3599 - accuracy: 0.8935 - val_loss: 0.3538 - val_accuracy: 0.8955
# Epoch 442/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3774 - accuracy: 0.8834 - val_loss: 0.3603 - val_accuracy: 0.8912
# Epoch 443/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3766 - accuracy: 0.8856 - val_loss: 0.4232 - val_accuracy: 0.8728
# Epoch 444/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3640 - accuracy: 0.8910 - val_loss: 0.3864 - val_accuracy: 0.8776
# Epoch 445/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3756 - accuracy: 0.8850 - val_loss: 0.3501 - val_accuracy: 0.9009
# Epoch 446/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3606 - accuracy: 0.8939 - val_loss: 0.4213 - val_accuracy: 0.8663
# Epoch 447/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3696 - accuracy: 0.8854 - val_loss: 0.3628 - val_accuracy: 0.8906
# Epoch 448/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3580 - accuracy: 0.8915 - val_loss: 0.3476 - val_accuracy: 0.8988
# Epoch 449/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3583 - accuracy: 0.8970 - val_loss: 0.4303 - val_accuracy: 0.8506
# Epoch 450/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3723 - accuracy: 0.8863 - val_loss: 0.3449 - val_accuracy: 0.9042
# Epoch 451/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3712 - accuracy: 0.8881 - val_loss: 0.3488 - val_accuracy: 0.9053
# Epoch 452/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3706 - accuracy: 0.8879 - val_loss: 0.3784 - val_accuracy: 0.8798
# Epoch 453/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3704 - accuracy: 0.8885 - val_loss: 0.3495 - val_accuracy: 0.9004
# Epoch 454/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3659 - accuracy: 0.8881 - val_loss: 0.4234 - val_accuracy: 0.8695
# Epoch 455/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3722 - accuracy: 0.8852 - val_loss: 0.3769 - val_accuracy: 0.8814
# Epoch 456/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3594 - accuracy: 0.8941 - val_loss: 0.3453 - val_accuracy: 0.9004
# Epoch 457/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3788 - accuracy: 0.8803 - val_loss: 0.4361 - val_accuracy: 0.8549
# Epoch 458/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3692 - accuracy: 0.8932 - val_loss: 0.3634 - val_accuracy: 0.8890
# Epoch 459/500
# 174/174 [==============================] - 7s 40ms/step - loss: 0.3641 - accuracy: 0.8870 - val_loss: 0.3830 - val_accuracy: 0.8847
# Epoch 460/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3583 - accuracy: 0.8957 - val_loss: 0.4134 - val_accuracy: 0.8706
# Epoch 461/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3776 - accuracy: 0.8852 - val_loss: 0.4562 - val_accuracy: 0.8338
# Epoch 462/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3761 - accuracy: 0.8812 - val_loss: 0.3875 - val_accuracy: 0.8760
# Epoch 463/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3666 - accuracy: 0.8897 - val_loss: 0.3491 - val_accuracy: 0.8982
# Epoch 464/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3617 - accuracy: 0.8928 - val_loss: 0.3630 - val_accuracy: 0.8982
# Epoch 465/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3728 - accuracy: 0.8850 - val_loss: 0.3576 - val_accuracy: 0.8993
# Epoch 466/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3646 - accuracy: 0.8903 - val_loss: 0.3433 - val_accuracy: 0.9020
# Epoch 467/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3798 - accuracy: 0.8816 - val_loss: 0.3578 - val_accuracy: 0.9004
# Epoch 468/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3526 - accuracy: 0.8973 - val_loss: 0.3425 - val_accuracy: 0.9036
# Epoch 469/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3662 - accuracy: 0.8874 - val_loss: 0.3493 - val_accuracy: 0.9020
# Epoch 470/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3548 - accuracy: 0.8957 - val_loss: 0.4263 - val_accuracy: 0.8663
# Epoch 471/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3789 - accuracy: 0.8802 - val_loss: 0.3710 - val_accuracy: 0.8831
# Epoch 472/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3609 - accuracy: 0.8937 - val_loss: 0.3511 - val_accuracy: 0.9063
# Epoch 473/500
# 174/174 [==============================] - 9s 50ms/step - loss: 0.3671 - accuracy: 0.8914 - val_loss: 0.3482 - val_accuracy: 0.9085
# Epoch 474/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3582 - accuracy: 0.8910 - val_loss: 0.3914 - val_accuracy: 0.8847
# Epoch 475/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3678 - accuracy: 0.8892 - val_loss: 0.3869 - val_accuracy: 0.8793
# Epoch 476/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3934 - accuracy: 0.8805 - val_loss: 0.3495 - val_accuracy: 0.8998
# Epoch 477/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3563 - accuracy: 0.8935 - val_loss: 0.3422 - val_accuracy: 0.8982
# Epoch 478/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3607 - accuracy: 0.8906 - val_loss: 0.3589 - val_accuracy: 0.8950
# Epoch 479/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3682 - accuracy: 0.8883 - val_loss: 0.3501 - val_accuracy: 0.9031
# Epoch 480/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3667 - accuracy: 0.8896 - val_loss: 0.3574 - val_accuracy: 0.8950
# Epoch 481/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3594 - accuracy: 0.8939 - val_loss: 0.3467 - val_accuracy: 0.9009
# Epoch 482/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3634 - accuracy: 0.8941 - val_loss: 0.3489 - val_accuracy: 0.9036
# Epoch 483/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3731 - accuracy: 0.8865 - val_loss: 0.3486 - val_accuracy: 0.8977
# Epoch 484/500
# 174/174 [==============================] - 6s 37ms/step - loss: 0.3611 - accuracy: 0.8933 - val_loss: 0.3544 - val_accuracy: 0.9004
# Epoch 485/500
# 174/174 [==============================] - 7s 42ms/step - loss: 0.3618 - accuracy: 0.8888 - val_loss: 0.5156 - val_accuracy: 0.7986
# Epoch 486/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3742 - accuracy: 0.8852 - val_loss: 0.3763 - val_accuracy: 0.8836
# Epoch 487/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3524 - accuracy: 0.8962 - val_loss: 0.4088 - val_accuracy: 0.8690
# Epoch 488/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3741 - accuracy: 0.8845 - val_loss: 0.3597 - val_accuracy: 0.8988
# Epoch 489/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3723 - accuracy: 0.8840 - val_loss: 0.4360 - val_accuracy: 0.8295
# Epoch 490/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3760 - accuracy: 0.8858 - val_loss: 0.3571 - val_accuracy: 0.8977
# Epoch 491/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3626 - accuracy: 0.8912 - val_loss: 0.3862 - val_accuracy: 0.8749
# Epoch 492/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3804 - accuracy: 0.8796 - val_loss: 0.3503 - val_accuracy: 0.8971
# Epoch 493/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3633 - accuracy: 0.8962 - val_loss: 0.3500 - val_accuracy: 0.9015
# Epoch 494/500
# 174/174 [==============================] - 6s 35ms/step - loss: 0.3727 - accuracy: 0.8841 - val_loss: 0.3722 - val_accuracy: 0.8836
# Epoch 495/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3680 - accuracy: 0.8915 - val_loss: 0.3891 - val_accuracy: 0.8776
# Epoch 496/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3641 - accuracy: 0.8908 - val_loss: 0.3948 - val_accuracy: 0.8776
# Epoch 497/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3675 - accuracy: 0.8905 - val_loss: 0.3529 - val_accuracy: 0.9009
# Epoch 498/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3613 - accuracy: 0.8919 - val_loss: 0.3600 - val_accuracy: 0.8993
# Epoch 499/500
# 174/174 [==============================] - 7s 41ms/step - loss: 0.3640 - accuracy: 0.8968 - val_loss: 0.3829 - val_accuracy: 0.8831
# Epoch 500/500
# 174/174 [==============================] - 6s 36ms/step - loss: 0.3648 - accuracy: 0.8921 - val_loss: 0.4281 - val_accuracy: 0.8435

# %% [markdown]
# The validation_split argument in Keras fit method specifies the fraction of the training data to be used as validation data. The model will not be trained on the validation data, but rather the validation data will be used to evaluate the model's training performance over the epochs on data it has not seen before.
#
# For example, if validation_split=0.2, then 20% of the training data will be used as validation data and the remaining 80% will be used as the training data. The validation data will be used to evaluate the model's performance after each epoch during training. The validation set is a portion of the training set to evaluate the training process, instead to evaluate the network we have to use a different dataset called testing dataset.

# %%
# list all data in training history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Plotting the Loss function and the MSE
# We can track the training accurancy to avoid overfitting by plotting the loss function and the MSE for each epoch. The MSE is a common metric to evaluate regession task. The lower the loss, the better the model performance. The purpose of the loss function is to evaluate how well the model is learning the patterns in the data and adjusting its weights and biases to make accurate predictions. So, when you train a model, you try to minimize the loss function by adjusting the model's parameters. In other evaluation metrics, such as accuracy or F1 score, the higher the value, the better the model performance.
# Ploting the training history

# %%
plt.figure(figsize=(16,5))
plt.title('arpeggio')
plt.subplot(1,2,1)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(1,2,2)
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
# Out:
# <ipython-input-10-97c39e790045>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %% [markdown]
# ## Model Evaluation
# Testing the model whit a testing set computing the loss function for an unseen dataset. fixare la cross validatin che non funziona

# %%
#divide in training set e test 
#the testing dataset have to be useen data but whith a trained target set, you can use a dataset belonging to a target that you did not train. 
#in the training the network see the label, in the tasting set it see the label only at the end, but shold be data from a studied label otherwise it has no sense. 
#it has to be data belonging to one of the category which you use during the training but unseen during the training stage.
#you have to split the training dataset to obtai a testing dataset 
"""
## Model evaluation 
from sklearn.model_selection import StratifiedKFold
# Define the number of folds
n_folds = 10

# Initialize the cross-validator
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Initialize lists to store the evaluation results
accuracy_scores = []
loss_scores = []

# Perform cross-validation
for train_idx, val_idx in kfold.split(X_train, Y_train):
    # Split the data into training and validation sets
    x_train_1, x_val_1 = X_train[train_idx], X_train[val_idx]
    y_train_1, y_val_1 = Y_train[train_idx], Y_train[val_idx]

    # Compile and train the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(x_train_1, y_train_1, epochs=10, batch_size=32, verbose=0)
    #y_val= np.argmax(y_val, axis=1)
    # Evaluate the model on the validation set
    scores = model.evaluate(x_val_1, y_val_1, verbose=0)

    # Store the evaluation results
    loss_scores.append(scores[0])
    accuracy_scores.append(scores[1])

# Calculate and print the average performance metrics
print("Average loss: ", np.mean(loss_scores))
print("Average accuracy: ", np.mean(accuracy_scores))
"""
model.evaluate(X_test,Y_test)
# Out:
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0234 - accuracy: 0.4239
# [0.02341608516871929, 0.42393070459365845]

# %% [markdown]
# Now we have to actualy try the regression, we could use the method model.predict

# %%
# Reshape the data to match the input shape of the model
new_data= pd_dataframe['pullOffHammerOn'][400]

new_data= np.reshape(new_data,(1,new_data.shape[0], new_data.shape[1]))
print(new_data.shape)
#new_data = new_data.reshape(1, -1)

# Make a prediction using the model
prediction = model.predict(new_data)
print(np.sum(prediction))
index= np.argmax(prediction)
print(np.argmax(prediction), prediction.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 400
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-450f5a47d58c> in <cell line: 2>()
#       1 # Reshape the data to match the input shape of the model
# ----> 2 new_data= pd_dataframe['pullOffHammerOn'][400]
#       3
#       4 new_data= np.reshape(new_data,(1,new_data.shape[0], new_data.shape[1]))
#       5 print(new_data.shape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 400

# %% [markdown]
# ## Exporting the model
# Now we want to save the model to use it in RawPower

# %%
# Save the model
model.save('sEMG_regression.h5')

# %% [markdown]
# be sure to have alla the requirements to run the model

# %%
# !pip freeze > requirements.txt
# !pip freeze

# %% [markdown]
# ## Further implementations

# %% [markdown]
# To keep track of the patterns of each single channel separately, you can use a multichannel LSTM model. This model has separate LSTM cells for each channel, which can learn to extract relevant features from the channel's data independently. You can then combine the outputs from each channel's LSTM cell to produce a final output.

# %%
"""
# Define input shape for each channel
input_shape = (timesteps, features_per_channel)

# Define input layers for each channel
input_channel1 = Input(shape=input_shape, name='input_channel1')
input_channel2 = Input(shape=input_shape, name='input_channel2')
input_channel3 = Input(shape=input_shape, name='input_channel3')
input_channel4 = Input(shape=input_shape, name='input_channel4')
input_channel5 = Input(shape=input_shape, name='input_channel5')
input_channel6 = Input(shape=input_shape, name='input_channel6')
input_channel7 = Input(shape=input_shape, name='input_channel7')
input_channel8 = Input(shape=input_shape, name='input_channel8')

# Define LSTM layers for each channel
lstm_channel1 = LSTM(32, return_sequences=True)(input_channel1)
lstm_channel2 = LSTM(32, return_sequences=True)(input_channel2)
lstm_channel3 = LSTM(32, return_sequences=True)(input_channel3)
lstm_channel4 = LSTM(32, return_sequences=True)(input_channel4)
lstm_channel5 = LSTM(32, return_sequences=True)(input_channel5)
lstm_channel6 = LSTM(32, return_sequences=True)(input_channel6)
lstm_channel7 = LSTM(32, return_sequences=True)(input_channel7)
lstm_channel8 = LSTM(32, return_sequences=True)(input_channel8)

# Concatenate outputs from all LSTM layers
concatenated = concatenate([lstm_channel1, lstm_channel2, lstm_channel3, lstm_channel4, lstm_channel5, lstm_channel6, lstm_channel7, lstm_channel8])

# Define output layer
output = Dense(5, activation='sigmoid')(concatenated)

# Define model
model = Model(inputs=[input_channel1, input_channel2, input_channel3, input_channel4, input_channel5, input_channel6, input_channel7, input_channel8], outputs=output)
"""

# %% [markdown]
# Once your model is compiled, you can train it using a supervised learning approach, where you associate specific input sEMG data streams with specific output parameter values. You can do this by creating a dataset that consists of pairs of input-output data points, where each input sEMG data stream is associated with a corresponding output parameter value.
#
# Assuming you have a dataset with N input-output data pairs, you can train your model using the fit method in Keras:

# %%
model.fit(X_train, y_train, batch_size=32, epochs=50)

# %% [markdown]
# In this example, X_train is a 3D tensor of shape (N, timesteps, input_dim) containing the input sEMG data streams, and y_train is a 2D tensor of shape (N, 5) containing the associated output parameter values. We're using a batch size of 32 and training for 50 epochs.
#
# ## Input definition: Tensor array
# In machine learning, a tensor is a mathematical object represented as a multi-dimensional array of numerical values. Tensors can be used to represent a wide variety of data types, including scalars (0-dimensional tensors), vectors (1-dimensional tensors), matrices (2-dimensional tensors), and higher-dimensional arrays (3-dimensional or higher-order tensors).
#
# In deep learning, tensors are used to represent both the input data and the parameters of the neural network.

# %% [markdown]
# Finally, once your model is trained, you can use it to predict the output parameter values for new sEMG data streams in real-time using the predict method:

# %%
y_pred = model.predict(X_new)

# %% [markdown]
# In this example, X_new is a 3D tensor of shape (1, timesteps, input_dim) containing a new sEMG data stream, and y_pred is a 2D tensor of shape (1, 5) containing the predicted output parameter values.

# %% [markdown]
# # Dataset preparation
# ## From pandas dataframe to Tensor
# To define a tensor from a Pandas DataFrame, you can use the .values attribute of the DataFrame, which returns a NumPy array containing the data in the DataFrame. You can then convert the NumPy array to a tensor using TensorFlow.
# ### How a dataset have to look like in Keras
# in Keras, a dataset typically consists of two separate arrays: the input data (features) and the target data (labels). The input data array should have shape (num_samples, input_dim) where num_samples is the number of samples and input_dim is the number of input features. The target data array should have shape (num_samples, num_classes) where num_samples is the number of samples and num_classes is the number of output classes.
#
# Alternatively, the dataset can be represented as a tuple or list of (x, y) pairs, where x is the input data array and y is the target data array. This is often the format returned by Keras' built-in dataset utilities and can be passed directly to the fit() method of a Keras model.

# %%
import pandas as pd
import tensorflow as tf

# Create a sample DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})

# Convert DataFrame to a tensor using TensorFlow
tensor = tf.convert_to_tensor(df.values, dtype=tf.float32)
print(tensor)

# %% [markdown]
# Now we want the model to have 24 inputs (RMS value) and 5 output. We need to pack one specific acquisition
#
# We create a buffer and we populate it with the stream of data taken by python associating it a specific outbuffer.

# %%
"""
# Initialize the input and output buffers
input_buffer = []
output_buffer = []

# Define the buffer size and time interval for accumulating data
buffer_size = 100
time_interval = 1.0

# Loop over the input stream
while True:
    # Read an input vector from the stream
    input_vector = read_input_vector()

    # Append the input vector to the input buffer
    input_buffer.append(input_vector)

    # Read the corresponding output value from the stream
    output_value = read_output_value()

    # Append the output value to the output buffer
    output_buffer.append(output_value)

    # If the buffer is full, train the model on the accumulated data
    if len(input_buffer) == buffer_size:
        # Convert the input and output buffers to numpy arrays
        X_train = np.array(input_buffer)
        y_train = np.array(output_buffer)

        # Train the model on the labeled training data
"""
